# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/testpng/10000.png
# /kaggle/input/rsna-bone-age/boneage-training-dataset.csv
# /kaggle/input/rsna-bone-age/boneage-test-dataset.csv
# /kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/4454.png
# /kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/4523.png
# /kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/4388.png
# /kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/4413.png
# /kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/4471.png
# /kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/4465.png
# /kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/4498.png
# /kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/4460.png
# /kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/4470.png
# /kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/4493.png
# ...

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation,Dropout, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization

# %%
train_csv = pd.read_csv('/kaggle/input/rsna-bone-age/boneage-training-dataset.csv')
test_csv = pd.read_csv('/kaggle/input/rsna-bone-age/boneage-test-dataset.csv')
test_csv.shape
train_csv.head()
# Out:
#      id  boneage   male
# 0  1377      180  False
# 1  1378       12  False
# 2  1379       94  False
# 3  1380      120   True
# 4  1381       82  False

# %%
train_csv=train_csv.iloc[:,:2]
train_csv.head()
# Out:
#      id  boneage
# 0  1377      180
# 1  1378       12
# 2  1379       94
# 3  1380      120
# 4  1381       82

# %%
train_csv["id"]=[str(i)+".png" for i in train_csv["id"]]
train_csv.head()
# Out:
#          id  boneage
# 0  1377.png      180
# 1  1378.png       12
# 2  1379.png       94
# 3  1380.png      120
# 4  1381.png       82

# %%
test_csv["Case ID"]=[str(i)+".png" for i in test_csv["Case ID"]]
test_csv.head()
# Out:
#     Case ID Sex
# 0  4360.png   M
# 1  4361.png   M
# 2  4362.png   M
# 3  4363.png   M
# 4  4364.png   M

# %%
train_link = ("/kaggle/input/rsna-bone-age/boneage-training-dataset/boneage-training-dataset/")
test_link = ('/kaggle/input/rsna-bone-age/boneage-test-dataset/boneage-test-dataset/')
print(len(os.listdir(train_link)))
print(len(os.listdir(test_link)))
# Out:
# 12611
# 200

# %%
boneage_mean = train_csv['boneage'].mean()
boneage_div = 2*train_csv['boneage'].std()
train_csv['boneage_zscore'] = train_csv['boneage'].map(lambda x: (x-boneage_mean)/boneage_div)
train_csv.dropna(inplace = True)
train_csv.sample(3)
# Out:
#              id  boneage  boneage_zscore
# 7365   9745.png       96       -0.380272
# 9576  12229.png      120       -0.088883
# 3760   5745.png      132        0.056812

# %%
train_datagen=ImageDataGenerator(rescale=1./255.,validation_split=0.10)
train_gen=train_datagen.flow_from_dataframe(dataframe=train_csv,
                           directory=train_link,
                           x_col="id",
                           y_col='boneage_zscore',
                           subset="training",
                           batch_size=64,
                           class_mode='raw',
                           target_size=(224,224))

valid_gen=train_datagen.flow_from_dataframe(dataframe=train_csv,
                           directory=train_link,
                           x_col="id",
                           y_col='boneage_zscore',
                           subset="validation",
                           batch_size=64,
                           class_mode='raw',
                           target_size=(224,224))
# Out:
# Found 11350 validated image filenames.
# Found 1261 validated image filenames.

# %%
test_datagen=ImageDataGenerator(rescale=1./255.)

test_gen=test_datagen.flow_from_dataframe(
dataframe=test_csv,
directory=test_link,
x_col="Case ID",
y_col=None,
batch_size=64,
shuffle=False,
class_mode=None,
target_size=(224,224))
# Out:
# Found 200 validated image filenames.

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),input_shape=(224,224,3)))
model.add(Activation("relu"))
#model.add(BatchNormalization())
model.add(Conv2D(32,(3,3)))
model.add(Activation("relu"))
#model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.1))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(1, activation='linear'))

#model.compile(optimizer = 'adam', loss = 'mse',metrics = ['accuracy'])


from keras.metrics import mean_absolute_error
def mae_months(in_gt, in_pred):
    return mean_absolute_error(boneage_div*in_gt, boneage_div*in_pred)

model.compile(optimizer = 'adam', loss = 'mse',
                           metrics = [mae_months])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_9 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# activation_11 (Activation)   (None, 222, 222, 32)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 220, 220, 32)      9248
# _________________________________________________________________
# activation_12 (Activation)   (None, 220, 220, 32)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 110, 110, 32)      0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 108, 108, 64)      18496
# ...

# %%
model.fit_generator(train_gen, 
                              validation_data = valid_gen, 
                              epochs = 10, 
                             use_multiprocessing=False, 
                             max_queue_size = 8)
# Out:
# Epoch 1/10
# 178/178 [==============================] - 405s 2s/step - loss: 1.1703 - mae_months: 39.3603 - val_loss: 0.3422 - val_mae_months: 37.7467
# Epoch 2/10
# 178/178 [==============================] - 360s 2s/step - loss: 0.1565 - mae_months: 25.5734 - val_loss: 0.3246 - val_mae_months: 36.9390
# Epoch 3/10
# 178/178 [==============================] - 356s 2s/step - loss: 0.1308 - mae_months: 23.3112 - val_loss: 0.2989 - val_mae_months: 35.8570
# Epoch 4/10
# 178/178 [==============================] - 352s 2s/step - loss: 0.1074 - mae_months: 20.8890 - val_loss: 0.3353 - val_mae_months: 36.0413
# Epoch 5/10
# 178/178 [==============================] - 350s 2s/step - loss: 0.0892 - mae_months: 19.0705 - val_loss: 0.4003 - val_mae_months: 36.3230
# Epoch 6/10
# 178/178 [==============================] - 352s 2s/step - loss: 0.0718 - mae_months: 17.1249 - val_loss: 0.3098 - val_mae_months: 36.2009
# Epoch 7/10
# ...

# %% [markdown]
# **#Visualization what convnets learn**

# %%
img_path = '/kaggle/input/testpng/10000.png'
from keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size = (224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis =0)
img_tensor /=255.

print(img_tensor.shape)
# Out:
# (1, 224, 224, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(img_tensor[0])
plt.show()

# %%
model.input
# Out:
# <tf.Tensor 'conv2d_9_input:0' shape=(?, 224, 224, 3) dtype=float32>

# %%
layer_outputs = [layer.output for layer in model.layers[:9]]

activation_model = models.Model(inputs= model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(img_tensor)

# %%
layer_outputs
# Out:
# [<tf.Tensor 'conv2d_9_1/BiasAdd:0' shape=(?, 222, 222, 32) dtype=float32>,
#  <tf.Tensor 'activation_11_1/Relu:0' shape=(?, 222, 222, 32) dtype=float32>,
#  <tf.Tensor 'conv2d_10_1/BiasAdd:0' shape=(?, 220, 220, 32) dtype=float32>,
#  <tf.Tensor 'activation_12_1/Relu:0' shape=(?, 220, 220, 32) dtype=float32>,
#  <tf.Tensor 'max_pooling2d_5_1/MaxPool:0' shape=(?, 110, 110, 32) dtype=float32>,
#  <tf.Tensor 'dropout_7_1/cond/Merge:0' shape=(?, 110, 110, 32) dtype=float32>,
#  <tf.Tensor 'conv2d_11_1/BiasAdd:0' shape=(?, 108, 108, 64) dtype=float32>,
#  <tf.Tensor 'activation_13_1/Relu:0' shape=(?, 108, 108, 64) dtype=float32>,
#  <tf.Tensor 'conv2d_12/BiasAdd:0' shape=(?, 106, 106, 128) dtype=float32>]

# %%
activation1 = activations[0]
print(activation1.shape)
# Out:
# (1, 222, 222, 32)

# %%
activation2 = activations[1]
print(activation2.shape)
# Out:
# (1, 222, 222, 32)

# %%
plt.matshow(activation2[0, :, :, 15],cmap='plasma')

# %%
activation3 = activations[2]
print(activation3.shape)
# Out:
# (1, 220, 220, 32)

# %%
activation4 = activations[3]
print(activation4.shape)
# Out:
# (1, 220, 220, 32)

# %%
activation5 = activations[4]
print(activation5.shape)
# Out:
# (1, 110, 110, 32)

# %%
# names of the layers, so you can have them as a part of your plot
layer_names = []
for layer in model.layers[:9]:
    layer_names.append(layer.name)

images_per_row = 16

# displays the feature maps
for layer_name, layer_activation in zip(layer_names, activations):
    
    # number of features in the feature map
    n_features = layer_activation.shape[-1]

    # the feature map has shape (1, size, size, n_features)
    size = layer_activation.shape[1]

    # tiles the activtion channels in this matrix
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))

    # tiles each filter into a big horizontal grid
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[
                0, :, :, col * images_per_row + row]
            
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(
                channel_image, 0, 255).astype('uint8')
            # displays the grid
            display_grid[
                col * size : (col + 1) * size,
                row * size : (row + 1) * size] = channel_image

    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='inferno')
